# %% [markdown]
# # Раздел 1. Основы теории вероятностей
# ---

# %% [markdown]
# ## Тема 1.1. Элементы комбинаторики
# ---

# %%
import scipy.special as sc

# %% [markdown]
# ### Задача 1.8
# > В конкурсе по 5 номинациям участвуют 10 кинофильмов. Сколько существует вариантов распределения призов, если по каждой номинации установлены: а) различные призы; б) одинаковые призы?

# %% [markdown]
# #### а) Различные призы

# %%
10 ** 5
# Out:
# 100000

# %% [markdown]
# #### б) Одинаковые призы

# %%
sc.comb(10 + 5 - 1, 5, exact=True)
# Out:
# 2002

# %% [markdown]
# ### Задача 1.9
# > Сколько существует семизначных чисел, состоящих из цифр 4, 5 и 6, в которых цифра 4 повторяется 3 раза, а цифры 5 и 6 — по 2 раза?

# %%
int(sc.factorial(7) / (sc.factorial(3) * sc.factorial(2) * sc.factorial(2)))
# Out:
# 210

# %% [markdown]
# ### Задача 1.10
# > Буквы Т, Е, И, Я, Р, О написаны на отдельных карточках. Ребенок берет карточки в случайном порядке и прикладывает одну к другой: а) 3 карточки; б) все 6 карточек. Какова вероятность того, что получится слово: а) «ТОР»; б) «ТЕОРИЯ»?

# %% [markdown]
# #### а) Получится слово «ТОР»

# %%
round(1 / (6 * 5 * 4), 4)
# Out:
# 0.0083

# %% [markdown]
# #### б) Получится слово «ТЕОРИЯ»

# %%
round(1 / sc.factorial(6), 4)
# Out:
# 0.0014

# %% [markdown]
# ### Задача 1.11
# > Используя условие задачи 1.10, найти вероятность того, что получится слово «АНАНАС», если на отдельных карточках написаны три буквы А, две буквы Н и одна буква С.

# %%
round(sc.factorial(3) * sc.factorial(2) / sc.factorial(6), 4)
# Out:
# 0.0167

# %% [markdown]
# ### Задача 1.16
# > За круглым столом рассаживаются 5 мужчин и 5 женщин. Найти вероятность того, что: а) никакие два лица одного пола не сядут рядом; б) супруги сядут рядом, если эти мужчины и женщины образуют 5 супружеских пар.

# %% [markdown]
# #### а) Никакие два лица одного пола не сядут рядом

# %%
round((2 * sc.factorial(5) * sc.factorial(5)) / sc.factorial(10), 4)
# Out:
# 0.0079

# %% [markdown]
# #### б) Супруги сядут рядом

# %%
round((sc.factorial(4) * (2 ** 5)) / sc.factorial(9), 4)
# Out:
# 0.0021

# %% [markdown]
# ### Задача 1.17
# > В купейный вагон (9 купе по 4 места) семи пассажирам продано 7 билетов. Найти вероятности того, что пассажиры попали: а) в два купе; б) в семь купе; в) в три купе.

# %% [markdown]
# #### а) Пассажиры попали в два купе

# %%
round(sc.comb(9, 2) * sc.comb(8, 7) / sc.comb(36, 7), 8)
# Out:
# 3.45e-05

# %% [markdown]
# #### б) Пассажиры попали в семь купе

# %%
round(sc.comb(9, 7) * (4 ** 7) / sc.comb(36, 7), 4)
# Out:
# 0.0707

# %% [markdown]
# #### в) Пассажиры попали в три купе

# %%
round(
    sc.comb(9, 3)
    * (sc.comb(12, 7) - sc.comb(3, 2) * sc.comb(8, 7))
    / sc.comb(36, 7),
    4,
)
# Out:
# 0.0077
